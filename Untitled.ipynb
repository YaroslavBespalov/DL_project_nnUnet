# %%
import sys
import torch
from albumentations import *
import matplotlib.pyplot as plt
# %matplotlib inline
sys.path.append('./src/')
import numpy as np
from load_function import get_list
from src.dataset import TrainDataset

# %%
def pre_transform(resize):
    transforms = []
#     transforms.append(Resize(resize, resize))
    return Compose(transforms)

# %%
folds = ['pancreas_100.nii.gz']

# %%
ds = TrainDataset('../', folds, pre_transform(256))

# %%
plt.imshow(ds[0]['image'].squeeze())

# %%
plt.imshow(ds[0]['mask'].squeeze())

# %%
....
